# %%
from pypalace import Config, Simulation,Tools
from pypalace.builder import Model, Domains, Boundaries, Solver

# %% [markdown]
# #### Look at the mesh attributes to help us define our config file below

# %%
meshfile = "tunable_xmon.bdf"
Tools.get_mesh_attributes(meshfile)
# Out:
#            Name ID     Type
# 0     substrate  1   Volume
# 1           air  2   Volume
# 2    xmon_cross  3  Surface
# 3    squid_Loop  4  Surface
# 4     flux_line  5  Surface
# 5     flux_port  6  Surface
# 6  ground_plane  7  Surface
# 7     far_field  8  Surface

# %% [markdown]
# ## Build a Palace config file for a magnetostatic simulation with SurfaceFlux postprocessing

# %% [markdown]
# #### Create config object and add config["Problem"] and config["Model"]

# %%
# create config object
my_config = Config("tunable_xmon.json")

# add Problem and Model blocks to config
my_config.add_Problem("Magnetostatic",Output="magneto_output")
my_config.add_Model(meshfile,L0=1e-6) # no adaptive mesh refinement, already finely meshed

# %% [markdown]
# #### define materials and boundary conditions

# %%
# define materials
silicon = Domains.Material([1],1.0,11.45,0.0) # silicon 
air = Domains.Material([2],1.0,1.0,0.0) # air
my_materials = [silicon,air] # material list for input into add_Domains()

# define boundary conditions
PECs = Boundaries.PEC([3,5,7,8]) # xmon cross, flux bias line, ground_plane, far_field
flux_port = Boundaries.SurfaceCurrent(Index=1,Attributes=[6],Direction="+X") # add surface current to the flux port to give flux line current 
my_BCs = [PECs,flux_port] # boundary condition list for input into add_Boundaries()

# %% [markdown]
# #### add surface flux postprocessing

# %%
# add our quasi-SQUID loop to SurfaceFlux postprocesssing so we can get magnetic flux through it
surfaceFlux_pp = Boundaries.Postprocessing_SurfaceFlux(Index=2,Attributes=[4],Type="Magnetic")
my_Boundaries_pp = [surfaceFlux_pp]

# %% [markdown]
# #### add Domains (materials) and Boundaries (BC and BC postprocessing) to config["Domains"] and config["Boundaries"], respectively.

# %%
# add config["Domains"] and config["Boundaries"] using our material and BC lists above
my_config.add_Domains(my_materials)
my_config.add_Boundaries(my_BCs,Postprocessing=my_Boundaries_pp)

# %% [markdown]
# #### add magnetostatic and linear solver parameters

# %%
magneto_params = Solver.Magnetostatic(Save=5)

Linear_params = Solver.Linear(Type="Default",
                              KSPType = "GMRES",
                              Tol = 1e-6,
                              MaxIts = 500) # takes quite a few iterations to converge
                              
my_config.add_Solver(Simulation=magneto_params,Order= 2,Linear=Linear_params)

# %%
my_config.print_config()
# Out:
# {
#   "Problem": {
#     "Type": "Magnetostatic",
#     "Verbose": 2,
#     "Output": "magneto_output"
#   },
#   "Model": {
#     "Mesh": "tunable_xmon.bdf",
#     "L0": 1e-06
#   },
#   "Domains": {
#     "Materials": [
#       {
#         "Attributes": [
#           1
#         ],
#         "Permeability": 1.0,
#         "Permittivity": 11.45,
#         "LossTan": 0.0
#       },
#       {
#         "Attributes": [
#           2
#         ],
#         "Permeability": 1.0,
#         "Permittivity": 1.0,
#         "LossTan": 0.0
#       }
#     ]
#   },
#   "Boundaries": {
#     "PEC": {
#       "Attributes": [
#         3,
#         5,
#         7,
#         8
#       ]
#     },
#     "SurfaceCurrent": [
#       {
#         "Index": 1,
#         "Attributes": [
#           6
#         ],
#         "Direction": "+X"
#       }
#     ],
#     "Postprocessing": {
#       "SurfaceFlux": [
#         {
#           "Index": 2,
#           "Attributes": [
#             4
#           ],
#           "Type": "Magnetic"
#         }
#       ]
#     }
#   },
#   "Solver": {
#     "Order": 2,
#     "Device": "CPU",
#     "Magnetostatic": {
#       "Save": 5
#     },
#     "Linear": {
#       "Type": "Default",
#       "KSPType": "GMRES",
#       "Tol": 1e-06,
#       "MaxIts": 500
#     }
#   }
# }

# %%
my_config.save_config()

# %% [markdown]
# ## Run Simulation Locally
#
# This is a somewhat computationally expensive simulation, recommended to run on an HPC instead.

# %%
#change to your install path 
path_to_palace = "/Users/firasabouzahr/Desktop/AWSPalace/install/bin/palace-arm64.bin" 

my_sim = Simulation(my_config,path_to_palace)
my_sim.run(n=5) # 5 mpi processses
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 5
#       2 path_to_palace = "/Users/firasabouzahr/Desktop/AWSPalace/install/bin/palace-arm64.bin"
#       4 my_sim = Simulation(my_config,path_to_palace)
# ----> 5 my_sim.run(n=5) # 5 mpi processses
#
# File ~/research/quantum circuit design/pyPalace/github/pypalace/simulation.py:39, in Simulation.run(self, n, HPC_options, custom_script_name)
#      36     self.config.save_config()
#      38 if HPC_options == None:
# ---> 39     command = subprocess.run(["mpirun", "-n",str(n),self.path_to_palace,self.path_to_json],capture_output=True,text=True)
#      40     print(command.stdout.strip())
#      41     print(command.stderr.strip())
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/subprocess.py:548, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     546 with Popen(*popenargs, **kwargs) as process:
#     547     try:
# --> 548         stdout, stderr = process.communicate(input, timeout=timeout)
#     549     except TimeoutExpired as exc:
#     550         process.kill()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/subprocess.py:1205, in Popen.communicate(self, input, timeout)
#    1202     endtime = None
#    1204 try:
# -> 1205     stdout, stderr = self._communicate(input, endtime, timeout)
#    1206 except KeyboardInterrupt:
#    1207     # https://bugs.python.org/issue25942
#    1208     # See the detailed comment in .wait().
#    1209     if timeout is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/subprocess.py:2057, in Popen._communicate(self, input, endtime, orig_timeout)
#    2050     self._check_timeout(endtime, orig_timeout,
#    2051                         stdout, stderr,
#    2052                         skip_check_and_raise=True)
#    2053     raise RuntimeError(  # Impossible :)
#    2054         '_check_timeout(..., skip_check_and_raise=True) '
#    2055         'failed to raise TimeoutExpired.')
# -> 2057 ready = selector.select(timeout)
#    2058 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2060 # XXX Rewrite these to use non-blocking I/O on the file
#    2061 # objects; they are no longer using C stdio!
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     413 ready = []
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#     417     return ready
#
# KeyboardInterrupt:
