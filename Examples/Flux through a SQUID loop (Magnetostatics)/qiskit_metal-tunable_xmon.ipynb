# %%
import qiskit_metal as metal
from qiskit_metal import designs, draw
from qiskit_metal import MetalGUI, Dict, open_docs
from qiskit_metal.qlibrary.qubits.transmon_cross_fl import TransmonCrossFL
from qiskit_metal.qlibrary.terminations.launchpad_wb import LaunchpadWirebond
from qiskit_metal.qlibrary.tlines.straight_path import RouteStraight

# %%
design = designs.DesignPlanar()
gui = MetalGUI(design)

# cpw width and dielectric gap size
t_width = '6um'
t_gap="4um"
# Out:
# 10:55PM 23s CRITICAL [_qt_message_handler]: line: 0, func: None(), file: None  WARNING: Populating font family aliases took 57 ms. Replace uses of missing font family "Courier" with one that exists to avoid this cost.

# %%
## define qubit ##
xmon_options = dict(fl_options = dict(t_width=t_width,t_gap=t_gap))
qubit = TransmonCrossFL(design, 'qubit', options=xmon_options)

# %%
## define launch pad for flux bias line ##
launch_options = dict(pos_x='-600um', pos_y='-600um', orientation='0',trace_width=t_width,trace_gap=t_gap)
lp = LaunchpadWirebond(design, 'launch_pad', options = launch_options)

# %%
## define cpw of flux bias line ##
route_opts = Dict(
    pin_inputs=Dict(
        start_pin=Dict(
            component='launch_pad',
            pin='tie'),
        end_pin=Dict(
            component='qubit',
            pin='flux_line' )),
    trace_width=t_width,
    trace_gap=t_gap)

flux_route = RouteStraight(design,'flux_route',options=route_opts)

gui.rebuild()
gui.autoscale()

# %%
## save as GDS @##
a_gds = design.renderers.gds
a_gds.export_to_gds("tunable_xmon.gds")
# Out:
# 10:55PM 24s WARNING [_import_junctions_to_one_cell]: Not able to find file:"../resources/Fake_Junctions.GDS".  Not used to replace junction. Checked directory:"/Users/firasabouzahr/research/quantum circuit design/pyPalace/github/Examples/resources".
# 1
